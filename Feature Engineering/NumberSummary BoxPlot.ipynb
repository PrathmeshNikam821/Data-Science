# %% [markdown]
# ### Number Summary and Box Plot

# %%
#minimum , maximum , median , Q1 , Q3 , IQR

# %%
import numpy as np

# %%
lst_marks = [45,32,56,76,89,54,56,90,86,76,98,99,67,74]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,maximum,median,Q1,Q3
# Out:
# (32.0, 99.0, 75.0, 56.0, 88.25)

# %%
IQR=Q3-Q1
IQR
# Out:
# 32.25

# %%
lower_fence = Q1-1.5*(IQR)
higher_fence = Q3+1.5*(IQR)

# %%
lower_fence,higher_fence
# Out:
# (7.625, 136.625)

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-2,-100.1,4,5,2,45,32,56,76,89,54,56,90,86,76,98,99,67,74,300,600,900,1000]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
